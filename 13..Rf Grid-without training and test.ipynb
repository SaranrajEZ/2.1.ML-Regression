# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Define the parameter grid
param_grid = {'criterion': ['squared_error', 'absolute_error'],
              'max_features': ['sqrt', 'log2', None],
              'n_estimators': [10, 100]}

# Initialize GridSearchCV
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

# Fit the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.137529      0.004337         0.017298        0.000928
# 1        1.304529      0.056183         0.039416        0.006954
# 2        0.106981      0.020180         0.006440        0.006106
# 3        1.219476      0.065066         0.031521        0.008660
# 4        0.185910      0.012051         0.007958        0.007955
# 5        1.803251      0.045063         0.031996        0.001811
# 6        0.351248      0.031743         0.010614        0.005562
# 7        3.306044      0.206612         0.036874        0.011185
# 8        0.349304      0.025789         0.003886        0.005643
# 9        3.434953      0.239568         0.041174        0.016166
# 10       0.587455      0.039993         0.008279        0.006856
# 11       5.107936      0.093007         0.026932        0.006005
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4    squared_error               None                 10
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 10
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 10
# 9   absolute_error               log2                100
# 10  absolute_error               None                 10
# 11  absolute_error               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.821802
# 1   {'criterion': 'squared_error', 'max_features':...           0.859718
# 2   {'criterion': 'squared_error', 'max_features':...           0.850507
# 3   {'criterion': 'squared_error', 'max_features':...           0.859052
# 4   {'criterion': 'squared_error', 'max_features':...           0.832405
# 5   {'criterion': 'squared_error', 'max_features':...           0.842606
# 6   {'criterion': 'absolute_error', 'max_features'...           0.833923
# 7   {'criterion': 'absolute_error', 'max_features'...           0.858094
# 8   {'criterion': 'absolute_error', 'max_features'...           0.838878
# 9   {'criterion': 'absolute_error', 'max_features'...           0.858936
# 10  {'criterion': 'absolute_error', 'max_features'...           0.839904
# 11  {'criterion': 'absolute_error', 'max_features'...           0.839387
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.771968           0.830552           0.812441
# 1            0.777182           0.861187           0.835526
# 2            0.763533           0.853471           0.811891
# 3            0.778087           0.862645           0.826497
# 4            0.750050           0.840287           0.803128
# 5            0.774674           0.860995           0.816751
# 6            0.748118           0.840562           0.820070
# 7            0.781232           0.862193           0.827572
# 8            0.760217           0.846010           0.814901
# 9            0.786067           0.861037           0.823488
# 10           0.764644           0.828914           0.812730
# 11           0.760685           0.855780           0.822914
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.827961         0.812945        0.021416               11
# 1            0.845295         0.835782        0.030799                1
# 2            0.826216         0.821124        0.032673                7
# 3            0.838889         0.833034        0.030496                4
# 4            0.819618         0.809098        0.032090               12
# 5            0.837161         0.826437        0.029475                5
# 6            0.827720         0.814078        0.033669                9
# 7            0.846487         0.835116        0.029498                2
# 8            0.838347         0.819671        0.031524                8
# 9            0.845373         0.834980        0.027876                3
# 10           0.819681         0.813175        0.025923               10
# 11           0.834433         0.822640        0.032730                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:50
# BMI:5
# Children:1
# Sex Male 0 or 1:4
# Smoker Yes 0 or 1:5

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[21507.8669618]
# C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
